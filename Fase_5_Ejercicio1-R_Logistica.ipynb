# %%
#Instalar las librerias
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#Cargar los datos
data = pd.read_csv("C:/Users/LUIS MEZA/Desktop/UNAD/ANALISIS DE DATOS/FASE 5/archive/framingham.csv")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
#Seleccionamos los datos
data[['sysBP','prevalentHyp']].head()
# Out:
#    sysBP  prevalentHyp
# 0  106.0             0
# 1  121.0             0
# 2  127.5             0
# 3  150.0             1
# 4  130.0             0

# %%
#sysBP
data[['sysBP','prevalentHyp']].plot.scatter(x='sysBP',y='prevalentHyp')
# Out:
# <Axes: xlabel='sysBP', ylabel='prevalentHyp'>

# %%
# pruebas de parametro
w = 0.09
b = -3.6
x = np.linspace(0,data['prevalentHyp'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))
# grafica de la recta
data.plot.scatter(x='sysBP',y='prevalentHyp')
plt.plot(x, y, color='black')
plt.ylim(0,data['diabetes'].max()*1.1)
plt.scatter(x, y, color='#A9E2F3')
# plt.grid()
plt.xlabel('Indice')
plt.ylabel('1:Positivo 0:Negativo')
plt.show()
